# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
img=cv2.imread('rainbow.jpg')
plt.imshow(img)

# %%
img=cv2.imread('rainbow.jpg',0)
plt.imshow(img,cmap='gray')

# %%
ret,thresh1=cv2.threshold(img,127,255,cv2.THRESH_BINARY_INV)

# %%
ret
# Out:
# 127.0

# %%
plt.imshow(thresh1,cmap='gray')

# %%
def show_pic(img):
    fig=plt.figure(figsize=(15,15))
    ax=fig.add_subplot(111)
    ax.imshow(img,cmap='gray')

# %%
img=cv2.imread('crosswords.jpg',0)
#plt.imshow(img,cmap='gray')
show_pic(img)

# %%
ret,th1=cv2.threshold(img,127,255,cv2.THRESH_BINARY_INV)

# %%
show_pic(img)

# %% [markdown]
# def show_pic(img):
#     fig=plt.figure(figsize=(15,15))
#     ax=fig.add_subplot(111)
#     ax.imshow(img,cmap='gray')

# %%
def show_pic(img):
    fig=plt.figure(figsize=(15,15))
    ax=fig.add_subplot(111)
    ax.imshow(img,cmap='gray')

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
img=cv2.imread('rainbow.jpg',0)

# %%
ret,thresh1=cv2.threshold(img,127,255,cv2.THRESH_TOZERO)

# %%
plt.imshow(img,cmap='gray')

# %%
plt.imshow(thresh1,cmap='gray')

# %%
img=cv2.imread('crosswords.jpg',0)

# %%
ret,thresh1=cv2.threshold(img,180,255,cv2.THRESH_BINARY)

# %%
plt.imshow(img,cmap='gray')

# %%
plt.imshow(thresh1,cmap='gray')

# %%
def show_pic(img):
    fig=plt.figure(figsize=(15,15))
    ax=fig.add_subplot(111)
    ax.imshow(img,cmap='gray')

# %%
show_pic(thresh1)

# %%
th2=cv2.adaptiveThreshold(img,255,cv2.ADAPTIVE_THRESH_MEAN_C,cv2.THRESH_BINARY,7,12)

# %%
def showpic(img):
    fig=plt.figure(figsize=(15,15))
    ax=fig.sub_plot(111)
    ax.imshow(img,cmap='gray')

# %%
showpic(img)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-f9feea4ac4a4> in <module>
# ----> 1 showpic(img)
#
# NameError: name 'img' is not defined
